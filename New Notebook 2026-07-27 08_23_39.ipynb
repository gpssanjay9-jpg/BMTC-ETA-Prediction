# %%
import gdown

file_id = "1Jl4UeYrfKDMAleavLHygQ_i_PQJU47Tu"

output = "/tmp/vehicle_positions.parquet"

gdown.download(
    id=file_id,
    output=output,
    quiet=False
)

# %%
import gdown
import shutil
import os

url = "https://drive.google.com/uc?id=1Jl4UeYrfKDMAleavLHygQ_i_PQJU47Tu"

# Download to the driver's local disk
local_file = "/tmp/routes_sequential.parquet"
gdown.download(url, local_file, quiet=False)

# Copy into your Unity Catalog Volume
target = "/Volumes/workspace/default/bmtceta/raw_gtfs/routes_sequential.parquet"

os.makedirs(os.path.dirname(target), exist_ok=True)
shutil.copy(local_file, target)

# %%
import gdown

file_id = "19ooyNG7a5-s7W-78lH7z-wBHOxKtJPi5"

output = "/tmp/vehicle_positions.csv"

gdown.download(
    id=file_id,
    output=output,
    quiet=False
)
